# %% [markdown]
# # Gold Price Prediction using Machine Learning with Python

# %%
import yfinance as yf
import pandas as pd
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression

# %%
df = yf.download('Gold',
                start='2001-01-01',
                end='2023-06-27',
                progress=False)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2001-01-02  16.379999  17.190001  16.320000  17.120001  12.320952  1817200
# 2001-01-03  17.200001  17.340000  16.200001  16.230000  11.680438  2095400
# 2001-01-04  16.150000  16.190001  15.700000  15.770000  11.349384  1620800
# 2001-01-05  15.880000  16.240000  15.240000  15.370000  11.061512  1679400
# 2001-01-08  15.520000  15.750000  15.360000  15.550000  11.191055   896200

# %%
df['Return'] = df['Adj Close'].pct_change() * 100
df['Lagged_Return'] = df.Return.shift()
df = df.dropna()
train = df['2001':'2021']
test = df['2022': '2023']
# Create train and test sets for dependent and independent variables
X_train = train["Lagged_Return"].to_frame()
y_train = train["Return"]
X_test = test["Lagged_Return"].to_frame()
y_test = test["Return"]

# %% [markdown]
# ## Using Linear Regression Model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

# %%
import matplotlib.pyplot as plt
out_of_sample_results = y_test.to_frame()
# Add a column of "out-of-sample" predictions to that dataframe:  
out_of_sample_results["Out-of-Sample Predictions"] = model.predict(X_test)
out_of_sample_results.plot(subplots=True, title='Gold prices, USD')
plt.show()
